# %% [markdown]
# # 🔥 Wildfire model prediction - Demo

# %% [markdown]
# Run the code below to start:

# %%
import importlib
import wildfire_prediction_demo

importlib.reload(wildfire_prediction_demo)

demo = wildfire_prediction_demo.create_demo_interface()
